# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
newsnx=pd.read_csv(r'\newsnx.csv')

# %% [markdown]
# SNX

# %%
df1=bollinger_bands(newsnx,3, 1)

# %%
q=buy_sell_bullinger(df1,'SumScores/NumTweets','BU','BL')
df1['Buy_sentimentBu'] = q[0]
df1['Sell_sentimentBu'] = q[1]

# %%
ploti(df1,'Buy_sentimentBu','Sell_sentimentBu')

# %%
print(pool)
plt.plot(hesab)
plt.show()
# Out:
# 2172.165182955492

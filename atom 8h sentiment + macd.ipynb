# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
newatom8h=pd.read_csv(r'E:\Tweets\model 5\newatom8h.csv')

# %%
ploti('Buy_sentimentBu','Sell_sentimentBu')

# %%
hesab=[]
balance=[]
balan=0
sahm=0
pool = 1000
for i in range(len(df1['SumScores/NumTweets'])):
    if df1['Buy_sentimentBu'][i] == df1['ClosePrice'][i]:
        sahm = pool / df1['ClosePrice'][i]
    if df1['Sell_sentimentBu'][i] == df1['ClosePrice'][i]:
        pool = sahm * df1['ClosePrice'][i]
        balan=sahm*df1['ClosePrice'][i]
        sahm=0
    if df1['Sell_sentimentBu'][i] !=df1['ClosePrice'][i] :
        if sahm != 0 :
            balan=sahm*df1['ClosePrice'][i]

    hesab.append(pool)
    balance.append(balan)


print(pool)
plt.plot(hesab)
plt.show()
# Out:
# 8831.600845823525

# %%
plt.plot(balance)
plt.show()
